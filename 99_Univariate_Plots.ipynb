# %% [markdown]
# # Examples doing plots with Univaraite data
#
# ## Import libraries

# %%
# Pandas
import pandas as pd

# Constants
from src import constants

# Seagull
from src.Seagull.Seagull import Seagull

# Plots
from src.Plot.V1Plot.V1Numerical.V1_Density import Density_plot

# %% [markdown]
# ### Where do you want to save your plots?
# You can either show the plots in the Jupyter Notebook (plot.show()) or save them in disk (plot.save()). For these example, we will use the default folder (/out/Plots/...) to save the images for later use.

# %%
save_folder = constants.DENSITY_PLOTS_PATH

# %% [markdown]
# ### Loading datasets
# For these examples, we will use the Iris and Spotify sets as Seagull object, and a custom dataset as Panda DataFrame object, to demostrate that the Plots works with either type of data.

# %%
# Load the Iris dataset
irisDF = Seagull()
irisDF.set_iris()

# Load the Spotify datasets
spotify_instances = Seagull.get_spotify_datasets()

spotify_ArtitstDF   = spotify_instances[0]
spotify_SongsDF     = spotify_instances[1]
spotify_ComposersDF = spotify_instances[2]

# Load a custom dataset
my_panda_data = {
    'ID': [1, 2, 3, 4, 5],                                                                               # Integer data
    'Weight': [60.5, 70.2, 55.9, 85.3, 68.7],                                                            # Float data
    'Birthday': pd.to_datetime(['1990-01-01', '1992-05-15', '1985-07-30', '1988-11-25', '1993-03-05']),  # Date data
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],                                                 # String data
    'Nationality': pd.Categorical(['American', 'British', 'Canadian', 'Dutch', 'Estonian'])              # Categorical data
}
panda_df = pd.DataFrame(my_panda_data)
# Out:
# ['A', 'A#', 'B', 'C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#']
# /home/gromenawer/Desktop/GIT/Seagull/src/Seagull/methods/data_categorical.py:230: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 948    NaN
# 949    NaN
# 950    NaN
# 951    NaN
# 952    NaN
# Name: 16, Length: 953, dtype: category
# Categories (12, object): ['A' < 'A#' < 'B' < 'C' ... 'F' < 'F#' < 'G' < 'G#']' has dtype incompatible with category, please explicitly cast to a compatible dtype first.
#   self.data.iloc[:, column_index] = self.data.iloc[:, column_index].cat.set_categories(new_categories, ordered=True)
# /home/gromenawer/Desktop/GIT/Seagull/src/Seagull/methods/data_categorical.py:262: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 948    NaN
# 949    NaN
# 950    NaN
# 951    NaN
# 952    NaN
# Name: 17, Length: 953, dtype: category
# Categories (2, object): ['Major', 'Minor']' has dtype incompatible with category, please explicitly cast to a compatible dtype first.
#   self.data.iloc[:, column_index] = self.data.iloc[:, column_index].cat.set_categories(new_categories, ordered=False)

# %% [markdown]
# ## Create a plot with random data and show it

# %%
my_plot = Density_plot()
my_plot.show()
# Out:
# /home/gromenawer/Desktop/GIT/Seagull/src/Plot/Plot.py:196: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   self.figure.show()

# %% [markdown]
# ## Create a plot with random data and save it
# This will be saved with the default name: "Density_Plot.png"

# %%
my_plot = Density_plot(folder_path = save_folder)
my_plot.save()
# Out:
# Saving...  /home/gromenawer/Desktop/GIT/Seagull/out/Examples/Plots/Density_Plots/Density_Plot.*

# %% [markdown]
# ## Create a plot and change the data afterwards
# This will be save in "Iris_dataset_sepal_length_cm_Density_Plot.png"

# %%
my_plot = Density_plot(folder_path = save_folder)
my_plot.init_from_seagull(irisDF, 0)
my_plot.save()                                                                            # "Iris_dataset_sepal_length_cm_Density_Plot.png"
# Out:
# Saving...  /home/gromenawer/Desktop/GIT/Seagull/out/Examples/Plots/Density_Plots/Iris_dataset_sepal_length_cm_Density_Plot.*

# %% [markdown]
# ## Create the plot and initilize it at the same time using the column name
# This will be saved as "Songs releases by month.png"

# %%
my_plot = Density_plot(spotify_SongsDF, "Released month",  save_folder,
                        filename = "Songs releases by month")
my_plot.save()                                                              # "Songs releases by month.png" (beware of spaces!)
                                                                            # Is still good idea to avoid spaces in filenames for LaTeX
# Out:
# Saving...  /home/gromenawer/Desktop/GIT/Seagull/out/Examples/Plots/Density_Plots/Songs releases by month.*

# %% [markdown]
# ## Create the plot and initilize it at the same time using the column index
# This will be saved as "Songs_popularity_percentiles.png"

# %%
# Column 7 is "in_spotify_playlists" column
my_plot = Density_plot(spotify_SongsDF, 7, save_folder,
                        filename = "Songs_popularity_percentiles")
my_plot.save()                                                              # Songs_popularity_percentiles.png
# Out:
# Saving...  /home/gromenawer/Desktop/GIT/Seagull/out/Examples/Plots/Density_Plots/Songs_popularity_percentiles.*

# %% [markdown]
# ## Create the plot and change the style
# Example on how to save a plot with different styles. This save the files "BMP in blue.png" and "BMP in fancy.png"
#
# In the Notebook "XX Playing with Styles" we will show more examples on how to set different default styles for the plots

# %%
# Create the plot and change the style
my_plot = Density_plot(spotify_SongsDF, "bpm", save_folder,
                        filename = "BPM in blue")                                          
my_plot.style(line_thickness = 5, color_line = 'blue', color_fill_start = 'lightblue',    # Plot the BMP with a blue style
                color_alpha_end = 0.1)
my_plot.save()                                                                            # "BMP in blue.png"

my_plot.change_filename("BPM_in_fancy")                                                   # Set the filename to "BMP in fancy"

my_plot.style(line_thickness = 5, color_line = 'green',                                   # Plot the BMP with a questionable
                color_fill_start = 'lightgreen', color_alpha_start = 1,                     # green to magenta shade style
                color_fill_end   = 'magenta',    color_alpha_end   = 0.0,
                color_alpha_stop = 0.5)
my_plot.save()                                                                            # "BMP in fancy.png"
# Out:
# Saving...  /home/gromenawer/Desktop/GIT/Seagull/out/Examples/Plots/Density_Plots/BPM in blue.*
# Saving...  /home/gromenawer/Desktop/GIT/Seagull/out/Examples/Plots/Density_Plots/BPM_in_fancy.*

# %%
    # Create the plot with a non-seagull object

    # Create the plot with previously saved plot state
